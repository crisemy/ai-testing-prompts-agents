# %% [markdown]
# # DeepEval Results Analysis
# This notebook loads the evaluation metrics generated by the LangChain framework.

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('eval_results.csv')
df.head()

# %%
pass_rate = (df['Success'] == True).mean() * 100
print(f"Overall Pass Rate: {pass_rate:.1f}%")
